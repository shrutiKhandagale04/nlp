# %% [markdown]
# spaCy is a free, open-source library for NLP in Python written in Cython. spaCy is designed to make it easy to build systems for information extraction or general-purpose natural language processing.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
nlp

# %%
introduction_doc = nlp(
"To start processing your input, you construct a Doc object. A Doc object is a sequence of Token objects representing a lexical token. Each Token object has information about a particular piece—typically one word—of text. You can instantiate a Doc object by calling the Language object with the input string as an argument")
type(introduction_doc)


[token.text for token in introduction_doc]
# Out:
# ['To',
#  'start',
#  'processing',
#  'your',
#  'input',
#  ',',
#  'you',
#  'construct',
#  'a',
#  'Doc',
#  'object',
#  '.',
#  'A',
#  'Doc',
#  'object',
#  'is',
#  'a',
#  'sequence',
#  'of',
#  'Token',
#  'objects',
#  'representing',
#  'a',
#  'lexical',
#  'token',
#  '.',
#  'Each',
#  'Token',
#  'object',
#  'has',
#  'information',
#  'about',
#  'a',
#  'particular',
#  'piece',
#  '—',
#  'typically',
#  'one',
#  'word',
#  '—',
#  'of',
#  'text',
#  '.',
#  'You',
#  'can',
#  'instantiate',
#  'a',
#  'Doc',
#  'object',
#  'by',
#  'calling',
#  'the',
#  'Language',
#  'object',
#  'with',
#  'the',
#  'input',
#  'string',
#  'as',
#  'an',
#  'argument']

# %%
import pathlib
file_name = "intro.txt"
introduction_doc = nlp(pathlib.Path(file_name).read_text(encoding="utf-8"))
print ([token.text for token in introduction_doc])
# Out:
# ['Lemmatization', 'is', 'the', 'process', 'of', 'reducing', 'inflected', 'forms', 'of', 'a', 'word', 'while', 'still', 'ensuring', 'that', 'the', 'reduced', 'form', 'belongs', 'to', 'the', 'language', '.', 'This', 'reduced', 'form', ',', 'or', 'root', 'word', ',', 'is', 'called', 'a', 'lemma', '.', '\n\n', 'For', 'example', ',', 'organizes', ',', 'organized', 'and', 'organizing', 'are', 'all', 'forms', 'of', 'organize', '.', 'Here', ',', 'organize', 'is', 'the', 'lemma', '.', 'The', 'inflection', 'of', 'a', 'word', 'allows', 'you', 'to', 'express', 'different', 'grammatical', 'categories', ',', 'like', 'tense', '(', 'organized', 'vs', 'organize', ')', ',', 'number', '(', 'trains', 'vs', 'train', ')', ',', 'and', 'so', 'on', '.', 'Lemmatization', 'is', 'necessary', 'because', 'it', 'helps', 'you', 'reduce', 'the', 'inflected', 'forms', 'of', 'a', 'word', 'so', 'that', 'they', 'can', 'be', 'analyzed', 'as', 'a', 'single', 'item', '.', 'It', 'can', 'also', 'help', 'you', 'normalize', 'the', 'text', '.']

# %%
nlp = spacy.load("en_core_web_sm")
about_doc = nlp(introduction_doc)
print([token for token in about_doc if not token.is_stop])
# Out:
# [Lemmatization, process, reducing, inflected, forms, word, ensuring, reduced, form, belongs, language, ., reduced, form, ,, root, word, ,, called, lemma, .,
#
# , example, ,, organizes, ,, organized, organizing, forms, organize, ., ,, organize, lemma, ., inflection, word, allows, express, different, grammatical, categories, ,, like, tense, (, organized, vs, organize, ), ,, number, (, trains, vs, train, ), ,, ., Lemmatization, necessary, helps, reduce, inflected, forms, word, analyzed, single, item, ., help, normalize, text, .]

# %%
for token in about_doc:
    if str(token) != str(token.lemma_):
        print(f"{str(token):>20} : {str(token.lemma_)}")
# Out:
#        Lemmatization : lemmatization
#                   is : be
#             reducing : reduce
#            inflected : inflect
#                forms : form
#             ensuring : ensure
#              reduced : reduce
#              belongs : belong
#                 This : this
#                   is : be
#               called : call
#                  For : for
#            organizes : organize
#            organized : organize
#                  are : be
#                forms : form
#                 Here : here
#                   is : be
#                  The : the
#               allows : allow
#           categories : category
#            organized : organize
#               trains : train
#        Lemmatization : lemmatization
#                   is : be
#                helps : help
#                forms : form
#             analyzed : analyze
#                   It : it

# %%
from collections import Counter
words = [
    token.text
    for token in about_doc
    if not token.is_stop and not token.is_punct
]
print(Counter(words).most_common(5))
# Out:
# [('word', 4), ('forms', 3), ('organize', 3), ('Lemmatization', 2), ('inflected', 2)]

# %%
Counter(
    [token.text for token in about_doc if not token.is_punct]
).most_common(5)
# Out:
# [('the', 6), ('of', 5), ('a', 5), ('is', 4), ('word', 4)]

# %%
for token in about_doc:
    print(
        f"""
TOKEN: {str(token)}
=====
TAG: {str(token.tag_):10} POS: {token.pos_}
EXPLANATION: {spacy.explain(token.tag_)}"""
    )
# Out:
# TOKEN: Lemmatization
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: is
# =====
# TAG: VBZ        POS: AUX
# EXPLANATION: verb, 3rd person singular present
#
# TOKEN: the
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: process
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: of
# =====
# TAG: IN         POS: ADP
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: reducing
# =====
# TAG: VBG        POS: VERB
# EXPLANATION: verb, gerund or present participle
#
# TOKEN: inflected
# =====
# TAG: VBN        POS: VERB
# EXPLANATION: verb, past participle
#
# TOKEN: forms
# =====
# TAG: NNS        POS: NOUN
# EXPLANATION: noun, plural
#
# TOKEN: of
# =====
# TAG: IN         POS: ADP
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: a
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: word
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: while
# =====
# TAG: IN         POS: SCONJ
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: still
# =====
# TAG: RB         POS: ADV
# EXPLANATION: adverb
#
# TOKEN: ensuring
# =====
# TAG: VBG        POS: VERB
# EXPLANATION: verb, gerund or present participle
#
# TOKEN: that
# =====
# TAG: IN         POS: SCONJ
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: the
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: reduced
# =====
# TAG: VBN        POS: VERB
# EXPLANATION: verb, past participle
#
# TOKEN: form
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: belongs
# =====
# TAG: VBZ        POS: VERB
# EXPLANATION: verb, 3rd person singular present
#
# TOKEN: to
# =====
# TAG: IN         POS: ADP
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: the
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: language
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: .
# =====
# TAG: .          POS: PUNCT
# EXPLANATION: punctuation mark, sentence closer
#
# TOKEN: This
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: reduced
# =====
# TAG: JJ         POS: ADJ
# EXPLANATION: adjective (English), other noun-modifier (Chinese)
#
# TOKEN: form
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: ,
# =====
# TAG: ,          POS: PUNCT
# EXPLANATION: punctuation mark, comma
#
# TOKEN: or
# =====
# TAG: CC         POS: CCONJ
# EXPLANATION: conjunction, coordinating
#
# TOKEN: root
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: word
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: ,
# =====
# TAG: ,          POS: PUNCT
# EXPLANATION: punctuation mark, comma
#
# TOKEN: is
# =====
# TAG: VBZ        POS: AUX
# EXPLANATION: verb, 3rd person singular present
#
# TOKEN: called
# =====
# TAG: VBN        POS: VERB
# EXPLANATION: verb, past participle
#
# TOKEN: a
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: lemma
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: .
# =====
# TAG: .          POS: PUNCT
# EXPLANATION: punctuation mark, sentence closer
#
# TOKEN:
#
#
# =====
# TAG: _SP        POS: SPACE
# EXPLANATION: whitespace
#
# TOKEN: For
# =====
# TAG: IN         POS: ADP
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: example
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: ,
# =====
# TAG: ,          POS: PUNCT
# EXPLANATION: punctuation mark, comma
#
# TOKEN: organizes
# =====
# TAG: VBZ        POS: VERB
# EXPLANATION: verb, 3rd person singular present
#
# TOKEN: ,
# =====
# TAG: ,          POS: PUNCT
# EXPLANATION: punctuation mark, comma
#
# TOKEN: organized
# =====
# TAG: VBN        POS: VERB
# EXPLANATION: verb, past participle
#
# TOKEN: and
# =====
# TAG: CC         POS: CCONJ
# EXPLANATION: conjunction, coordinating
#
# TOKEN: organizing
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: are
# =====
# TAG: VBP        POS: AUX
# EXPLANATION: verb, non-3rd person singular present
#
# TOKEN: all
# =====
# TAG: DT         POS: PRON
# EXPLANATION: determiner
#
# TOKEN: forms
# =====
# TAG: NNS        POS: NOUN
# EXPLANATION: noun, plural
#
# TOKEN: of
# =====
# TAG: IN         POS: ADP
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: organize
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: .
# =====
# TAG: .          POS: PUNCT
# EXPLANATION: punctuation mark, sentence closer
#
# TOKEN: Here
# =====
# TAG: RB         POS: ADV
# EXPLANATION: adverb
#
# TOKEN: ,
# =====
# TAG: ,          POS: PUNCT
# EXPLANATION: punctuation mark, comma
#
# TOKEN: organize
# =====
# TAG: VB         POS: VERB
# EXPLANATION: verb, base form
#
# TOKEN: is
# =====
# TAG: VBZ        POS: AUX
# EXPLANATION: verb, 3rd person singular present
#
# TOKEN: the
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: lemma
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: .
# =====
# TAG: .          POS: PUNCT
# EXPLANATION: punctuation mark, sentence closer
#
# TOKEN: The
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: inflection
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: of
# =====
# TAG: IN         POS: ADP
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: a
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: word
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: allows
# =====
# TAG: VBZ        POS: VERB
# EXPLANATION: verb, 3rd person singular present
#
# TOKEN: you
# =====
# TAG: PRP        POS: PRON
# EXPLANATION: pronoun, personal
#
# TOKEN: to
# =====
# TAG: TO         POS: PART
# EXPLANATION: infinitival "to"
#
# TOKEN: express
# =====
# TAG: VB         POS: VERB
# EXPLANATION: verb, base form
#
# TOKEN: different
# =====
# TAG: JJ         POS: ADJ
# EXPLANATION: adjective (English), other noun-modifier (Chinese)
#
# TOKEN: grammatical
# =====
# TAG: JJ         POS: ADJ
# EXPLANATION: adjective (English), other noun-modifier (Chinese)
#
# TOKEN: categories
# =====
# TAG: NNS        POS: NOUN
# EXPLANATION: noun, plural
#
# TOKEN: ,
# =====
# TAG: ,          POS: PUNCT
# EXPLANATION: punctuation mark, comma
#
# TOKEN: like
# =====
# TAG: IN         POS: ADP
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: tense
# =====
# TAG: JJ         POS: ADJ
# EXPLANATION: adjective (English), other noun-modifier (Chinese)
#
# TOKEN: (
# =====
# TAG: -LRB-      POS: PUNCT
# EXPLANATION: left round bracket
#
# TOKEN: organized
# =====
# TAG: VBN        POS: VERB
# EXPLANATION: verb, past participle
#
# TOKEN: vs
# =====
# TAG: IN         POS: ADP
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: organize
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: )
# =====
# TAG: -RRB-      POS: PUNCT
# EXPLANATION: right round bracket
#
# TOKEN: ,
# =====
# TAG: ,          POS: PUNCT
# EXPLANATION: punctuation mark, comma
#
# TOKEN: number
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: (
# =====
# TAG: -LRB-      POS: PUNCT
# EXPLANATION: left round bracket
#
# TOKEN: trains
# =====
# TAG: NNS        POS: NOUN
# EXPLANATION: noun, plural
#
# TOKEN: vs
# =====
# TAG: IN         POS: ADP
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: train
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: )
# =====
# TAG: -RRB-      POS: PUNCT
# EXPLANATION: right round bracket
#
# TOKEN: ,
# =====
# TAG: ,          POS: PUNCT
# EXPLANATION: punctuation mark, comma
#
# TOKEN: and
# =====
# TAG: CC         POS: CCONJ
# EXPLANATION: conjunction, coordinating
#
# TOKEN: so
# =====
# TAG: RB         POS: ADV
# EXPLANATION: adverb
#
# TOKEN: on
# =====
# TAG: RB         POS: ADV
# EXPLANATION: adverb
#
# TOKEN: .
# =====
# TAG: .          POS: PUNCT
# EXPLANATION: punctuation mark, sentence closer
#
# TOKEN: Lemmatization
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: is
# =====
# TAG: VBZ        POS: AUX
# EXPLANATION: verb, 3rd person singular present
#
# TOKEN: necessary
# =====
# TAG: JJ         POS: ADJ
# EXPLANATION: adjective (English), other noun-modifier (Chinese)
#
# TOKEN: because
# =====
# TAG: IN         POS: SCONJ
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: it
# =====
# TAG: PRP        POS: PRON
# EXPLANATION: pronoun, personal
#
# TOKEN: helps
# =====
# TAG: VBZ        POS: VERB
# EXPLANATION: verb, 3rd person singular present
#
# TOKEN: you
# =====
# TAG: PRP        POS: PRON
# EXPLANATION: pronoun, personal
#
# TOKEN: reduce
# =====
# TAG: VB         POS: VERB
# EXPLANATION: verb, base form
#
# TOKEN: the
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: inflected
# =====
# TAG: JJ         POS: ADJ
# EXPLANATION: adjective (English), other noun-modifier (Chinese)
#
# TOKEN: forms
# =====
# TAG: NNS        POS: NOUN
# EXPLANATION: noun, plural
#
# TOKEN: of
# =====
# TAG: IN         POS: ADP
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: a
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: word
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: so
# =====
# TAG: IN         POS: SCONJ
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: that
# =====
# TAG: IN         POS: SCONJ
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: they
# =====
# TAG: PRP        POS: PRON
# EXPLANATION: pronoun, personal
#
# TOKEN: can
# =====
# TAG: MD         POS: AUX
# EXPLANATION: verb, modal auxiliary
#
# TOKEN: be
# =====
# TAG: VB         POS: AUX
# EXPLANATION: verb, base form
#
# TOKEN: analyzed
# =====
# TAG: VBN        POS: VERB
# EXPLANATION: verb, past participle
#
# TOKEN: as
# =====
# TAG: IN         POS: ADP
# EXPLANATION: conjunction, subordinating or preposition
#
# TOKEN: a
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: single
# =====
# TAG: JJ         POS: ADJ
# EXPLANATION: adjective (English), other noun-modifier (Chinese)
#
# TOKEN: item
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: .
# =====
# TAG: .          POS: PUNCT
# EXPLANATION: punctuation mark, sentence closer
#
# TOKEN: It
# =====
# TAG: PRP        POS: PRON
# EXPLANATION: pronoun, personal
#
# TOKEN: can
# =====
# TAG: MD         POS: AUX
# EXPLANATION: verb, modal auxiliary
#
# TOKEN: also
# =====
# TAG: RB         POS: ADV
# EXPLANATION: adverb
#
# TOKEN: help
# =====
# TAG: VB         POS: VERB
# EXPLANATION: verb, base form
#
# TOKEN: you
# =====
# TAG: PRP        POS: PRON
# EXPLANATION: pronoun, personal
#
# TOKEN: normalize
# =====
# TAG: VB         POS: VERB
# EXPLANATION: verb, base form
#
# TOKEN: the
# =====
# TAG: DT         POS: DET
# EXPLANATION: determiner
#
# TOKEN: text
# =====
# TAG: NN         POS: NOUN
# EXPLANATION: noun, singular or mass
#
# TOKEN: .
# =====
# TAG: .          POS: PUNCT
# EXPLANATION: punctuation mark, sentence closer

# %%
nouns = []
adjectives = []
for token in about_doc:
    if token.pos_ == "NOUN":
        nouns.append(token)
    if token.pos_ == "ADJ":
        adjectives.append(token)


nouns

adjectives
# Out:
# [reduced, different, grammatical, tense, necessary, inflected, single]

# %%
from spacy import displacy

displacy.serve(about_doc, style="dep")
# Out:
# c:\Users\Shruti\AppData\Local\Programs\Python\Python312\Lib\site-packages\spacy\displacy\__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c9ec2f69eab54af3b00a2068763adb39-0" class="displacy" width="18425" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Lemmatization</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">process</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">reducing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">inflected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">forms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">word</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">while</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">still</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">ensuring</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">reduced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">form</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">belongs</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">language.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">This</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">reduced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">form,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">root</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">word,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fil
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
# 127.0.0.1 - - [13/Aug/2024 11:09:06] "GET / HTTP/1.1" 200 84987
# 127.0.0.1 - - [13/Aug/2024 11:09:06] "GET /favicon.ico HTTP/1.1" 200 84987
# Shutting down server on port 5000.

# %%
def is_token_allowed(token):
    return bool(
        token
        and str(token).strip()
        and not token.is_stop
        and not token.is_punct
    )

def preprocess_token(token):
    return token.lemma_.strip().lower()

complete_filtered_tokens = [
    preprocess_token(token)
    for token in about_doc
    if is_token_allowed(token)
]

complete_filtered_tokens
# Out:
# ['lemmatization',
#  'process',
#  'reduce',
#  'inflect',
#  'form',
#  'word',
#  'ensure',
#  'reduce',
#  'form',
#  'belong',
#  'language',
#  'reduced',
#  'form',
#  'root',
#  'word',
#  'call',
#  'lemma',
#  'example',
#  'organize',
#  'organize',
#  'organizing',
#  'form',
#  'organize',
#  'organize',
#  'lemma',
#  'inflection',
#  'word',
#  'allow',
#  'express',
#  'different',
#  'grammatical',
#  'category',
#  'like',
#  'tense',
#  'organize',
#  'vs',
#  'organize',
#  'number',
#  'train',
#  'vs',
#  'train',
#  'lemmatization',
#  'necessary',
#  'help',
#  'reduce',
#  'inflected',
#  'form',
#  'word',
#  'analyze',
#  'single',
#  'item',
#  'help',
#  'normalize',
#  'text']
